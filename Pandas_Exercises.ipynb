# %%
import numpy as nump

# %%
import pandas as pd

# %%
df = pd.read_csv('movies_2.csv')

# %%
df.head(5)
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count  \
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0
#
#                                              Summary
# 0  After a single, career-minded woman is left on...
# 1  An old Jewish woman and her African-American c...
# ...

# %%
df.shape
# Out:
# (616, 11)

# %% [markdown]
# I have 616 rows and 11 columns

# %%
df.info
# Out:
# <bound method DataFrame.info of      MovieID                                  Title MPAA Rating       Budget  \
# 0          1                     Look Who's Talking       PG-13    7500000.0
# 1          2                     Driving Miss Daisy          PG    7500000.0
# 2          3                         Turner & Hooch          PG   13000000.0
# 3          4             Born on the Fourth of July           R   14000000.0
# 4          5                        Field of Dreams          PG   15000000.0
# ..       ...                                    ...         ...          ...
# 611      612                            Toy Story 4           G  200000000.0
# 612      613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613      614                          The Lion King          PG  250000000.0
# 614      615                      Avengers: Endgame       PG-13  356000000.0
# 615        0                                    NaN         NaN          NaN
#
# ...

# %%
df.dtypes
# Out:
# MovieID           int64
# Title            object
# MPAA Rating      object
# Budget          float64
# Gross           float64
# Release Date     object
# Genre            object
# Runtime         float64
# Rating          float64
# Rating Count    float64
# Summary          object
# dtype: object

# %%
df.isna()
# Out:
#      MovieID  Title  MPAA Rating  Budget  Gross  Release Date  Genre  Runtime  \
# 0      False  False        False   False  False         False  False    False
# 1      False  False        False   False  False         False  False    False
# 2      False  False        False   False  False         False  False    False
# 3      False  False        False   False  False         False  False    False
# 4      False  False        False   False  False         False  False    False
# ..       ...    ...          ...     ...    ...           ...    ...      ...
# 611    False  False        False   False  False         False  False    False
# 612    False  False        False   False  False         False  False    False
# 613    False  False        False   False  False         False  False    False
# 614    False  False        False   False  False         False  False    False
# 615    False   True         True    True   True          True   True     True
#
# ...

# %%
df.isnull()
# Out:
#      MovieID  Title  MPAA Rating  Budget  Gross  Release Date  Genre  Runtime  \
# 0      False  False        False   False  False         False  False    False
# 1      False  False        False   False  False         False  False    False
# 2      False  False        False   False  False         False  False    False
# 3      False  False        False   False  False         False  False    False
# 4      False  False        False   False  False         False  False    False
# ..       ...    ...          ...     ...    ...           ...    ...      ...
# 611    False  False        False   False  False         False  False    False
# 612    False  False        False   False  False         False  False    False
# 613    False  False        False   False  False         False  False    False
# 614    False  False        False   False  False         False  False    False
# 615    False   True         True    True   True          True   True     True
#
# ...

# %%
df['MPAA Rating'].isna().sum()
# Out:
# 1

# %%
# COUNT THE AMOUNT OF NaN IN THE DATAFRAME 

df['Budget'].isna().sum()
df['Gross'].isna().sum()
df['Release Date'].isna().sum()
df['Genre'].isna().sum()
df['Runtime'].isna().sum()
df['Rating'].isna().sum()
df['Rating Count'].isna().sum()
# Out:
# 108

# %% [markdown]
# ### REMOVE A COLUM

# %%
df.drop(["Summary"], axis=1, inplace = True)

# %%
df.head(5)
# Out:
#    MovieID                       Title MPAA Rating      Budget        Gross  \
# 0        1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1        2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2        3              Turner & Hooch          PG  13000000.0   71079915.0
# 3        4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4        5             Field of Dreams          PG  15000000.0   84431625.0
#
#   Release Date    Genre  Runtime  Rating  Rating Count
# 0   1989-10-12  Romance     93.0     5.9       73638.0
# 1   1989-12-13   Comedy     99.0     7.4       91075.0
# 2   1989-07-28    Crime    100.0     7.2       91415.0
# 3   1989-12-20      War    145.0     7.2       91415.0
# 4   1989-04-21    Drama    107.0     7.5      101702.0

# %% [markdown]
# ### Rename label in one or several column

# %%
df.rename(columns={'MovieID': 'movie_id','Title': 'title', 'MPAA Rating':'mpaa_rating','Budget': 'budget($)', 'Gross': 'gross($)', 'Release Date': 'release_date', 'Genre':'genre', 'Runtime':'runtime(min)', 'Rating':'rating', 'Rating Count':'rating_count'},inplace=True)

# %%
df.head(5)
# Out:
#    movie_id                       title mpaa_rating   budget($)     gross($)  \
# 0         1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1         2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2         3              Turner & Hooch          PG  13000000.0   71079915.0
# 3         4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4         5             Field of Dreams          PG  15000000.0   84431625.0
#
#   release_date    genre  runtime(min)  rating  rating_count
# 0   1989-10-12  Romance          93.0     5.9       73638.0
# 1   1989-12-13   Comedy          99.0     7.4       91075.0
# 2   1989-07-28    Crime         100.0     7.2       91415.0
# 3   1989-12-20      War         145.0     7.2       91415.0
# 4   1989-04-21    Drama         107.0     7.5      101702.0

# %% [markdown]
# ### Deleting a row

# %%
df.drop([615])
# Out:
#      movie_id                                  title mpaa_rating    budget($)  \
# 0           1                     Look Who's Talking       PG-13    7500000.0
# 1           2                     Driving Miss Daisy          PG    7500000.0
# 2           3                         Turner & Hooch          PG   13000000.0
# 3           4             Born on the Fourth of July           R   14000000.0
# 4           5                        Field of Dreams          PG   15000000.0
# ..        ...                                    ...         ...          ...
# 610       611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611       612                            Toy Story 4           G  200000000.0
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613       614                          The Lion King          PG  250000000.0
# 614       615                      Avengers: Endgame       PG-13  356000000.0
#
# ...

# %% [markdown]
# ### other way with index -1

# %%
df.drop(df.index[-1], inplace=True)

# %%
df['rating_count'].isna().sum()
# Out:
# 107

# %% [markdown]
# ### Method to calculate missing value

# %%
df["rating"].fillna(value=df["rating"].median(), inplace=True)

df["rating_count"].fillna(value=df["rating_count"].median(), inplace=True)

# %%
df.duplicated().sum()
 # By default(keep='first'), duplicated() marks all duplicate rows as True, except for the first occurrence, which is marked as False.
# Out:
# 0

# %% [markdown]
# ### To visualize duplicates in Data Frame

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [movie_id, title, mpaa_rating, budget($), gross($), release_date, genre, runtime(min), rating, rating_count]
# Index: []

# %%
#df[df.duplicated("titles")]

# %% [markdown]
# ### Identify the amount of unique values

# %%
df["title"].nunique()
# Out:
# 609

# %%
df
# Out:
#      movie_id                                  title mpaa_rating    budget($)  \
# 0           1                     Look Who's Talking       PG-13    7500000.0
# 1           2                     Driving Miss Daisy          PG    7500000.0
# 2           3                         Turner & Hooch          PG   13000000.0
# 3           4             Born on the Fourth of July           R   14000000.0
# 4           5                        Field of Dreams          PG   15000000.0
# ..        ...                                    ...         ...          ...
# 610       611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611       612                            Toy Story 4           G  200000000.0
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 613       614                          The Lion King          PG  250000000.0
# 614       615                      Avengers: Endgame       PG-13  356000000.0
#
# ...

# %% [markdown]
# ### See duplicates (the first duplicate in this case)

# %%
res = df[df.duplicated(subset=['title'])]

# %%
res
# Out:
#      movie_id                         title mpaa_rating    budget($)  \
# 249       250             Jurassic Park III       PG-13   93000000.0
# 501       502  Teenage Mutant Ninja Turtles       PG-13  125000000.0
# 504       505                      Godzilla       PG-13  160000000.0
# 565       566          Beauty and the Beast          PG  160000000.0
# 609       610                       Aladdin          PG  183000000.0
# 613       614                 The Lion King          PG  250000000.0
#
#          gross($) release_date      genre  runtime(min)  rating  rating_count
# 249  3.687808e+08   2001-07-18  Adventure          92.0     5.9      280110.0
# 501  4.772000e+08   2014-08-07     Action         101.0     5.8      194073.0
# 504  5.290761e+08   2014-05-14   Thriller         123.0     6.4      359438.0
# 565  1.262886e+09   2017-03-16      Drama         129.0     6.9      240347.5
# 609  1.049000e+09   2019-05-08    Fantasy         128.0     6.9      240347.5
# ...

# %% [markdown]
# ### Drop all the duplicates (first elements)

# %%
df.drop_duplicates(subset=['title'], keep='first')
# Out:
#      movie_id                                  title mpaa_rating    budget($)  \
# 0           1                     Look Who's Talking       PG-13    7500000.0
# 1           2                     Driving Miss Daisy          PG    7500000.0
# 2           3                         Turner & Hooch          PG   13000000.0
# 3           4             Born on the Fourth of July           R   14000000.0
# 4           5                        Field of Dreams          PG   15000000.0
# ..        ...                                    ...         ...          ...
# 608       609                         Captain Marvel       PG-13  175000000.0
# 610       611         Godzilla: King of the Monsters       PG-13  200000000.0
# 611       612                            Toy Story 4           G  200000000.0
# 612       613  Fast & Furious Presents: Hobbs & Shaw       PG-13  200000000.0
# 614       615                      Avengers: Endgame       PG-13  356000000.0
#
# ...

# %% [markdown]
# ### Change data type of a column into integers

# %%
df['budget($)'].astype(int)
# Out:
# 0        7500000
# 1        7500000
# 2       13000000
# 3       14000000
# 4       15000000
#          ...
# 610    200000000
# 611    200000000
# 612    200000000
# 613    250000000
# 614    356000000
# Name: budget($), Length: 615, dtype: int64

# %%
df.head()
# Out:
#    movie_id                       title mpaa_rating   budget($)     gross($)  \
# 0         1          Look Who's Talking       PG-13   7500000.0  296000000.0
# 1         2          Driving Miss Daisy          PG   7500000.0  145793296.0
# 2         3              Turner & Hooch          PG  13000000.0   71079915.0
# 3         4  Born on the Fourth of July           R  14000000.0  161001698.0
# 4         5             Field of Dreams          PG  15000000.0   84431625.0
#
#   release_date    genre  runtime(min)  rating  rating_count
# 0   1989-10-12  Romance          93.0     5.9       73638.0
# 1   1989-12-13   Comedy          99.0     7.4       91075.0
# 2   1989-07-28    Crime         100.0     7.2       91415.0
# 3   1989-12-20      War         145.0     7.2       91415.0
# 4   1989-04-21    Drama         107.0     7.5      101702.0

# %%
# Before converting a column into integers, we may want to check if the column doesn't contain NaN or non-numeric values, otherwise conversion will fail 

# Fill missing values with 0 before converting 

df['budget($)'] = df['budget($)'].fillna(0).astype(int)

# %%
# Here we want to replace the values containing a comma by nothing 

df['budget($)'].astype(str).str.replace(',', '').astype(int)
# Out:
# /Users/pierreloyal/anaconda3/lib/python3.11/site-packages/IPython/core/displayhook.py:281: UserWarning: Output cache limit (currently 1000 entries) hit.
# Flushing oldest 200 entries.
#   warn('Output cache limit (currently {sz} entries) hit.\n'
# 0        7500000
# 1        7500000
# 2       13000000
# 3       14000000
# 4       15000000
#          ...
# 610    200000000
# 611    200000000
# 612    200000000
# 613    250000000
# 614    356000000
# Name: budget($), Length: 615, dtype: int64

# %% [markdown]
# ### Replace the Gross Values with integers

# %%
df['gross($)'].astype(int)
# Out:
# 0       296000000
# 1       145793296
# 2        71079915
# 3       161001698
# 4        84431625
#           ...
# 610     385900000
# 611    1062000000
# 612     759400000
# 613    1632000000
# 614    2796000000
# Name: gross($), Length: 615, dtype: int64

# %% [markdown]
# ### Conversion of release_date column into a data time so pandas can understand and manipulate as dates

# %%
df['release_date'] = pd.to_datetime(df['release_date'])

# %% [markdown]
# ### To change the date configuration YYYY-MM-DD into DD-MM-YYYY

# %%
df['release_date']=df['release_date'].dt.strftime('%d-%m-%y')

# %%
df.head()
# Out:
#    movie_id                       title mpaa_rating  budget($)     gross($)  \
# 0         1          Look Who's Talking       PG-13    7500000  296000000.0
# 1         2          Driving Miss Daisy          PG    7500000  145793296.0
# 2         3              Turner & Hooch          PG   13000000   71079915.0
# 3         4  Born on the Fourth of July           R   14000000  161001698.0
# 4         5             Field of Dreams          PG   15000000   84431625.0
#
#   release_date    genre  runtime(min)  rating  rating_count
# 0     12-10-89  Romance          93.0     5.9       73638.0
# 1     13-12-89   Comedy          99.0     7.4       91075.0
# 2     28-07-89    Crime         100.0     7.2       91415.0
# 3     20-12-89      War         145.0     7.2       91415.0
# 4     21-04-89    Drama         107.0     7.5      101702.0

# %% [markdown]
# ### Filter Data according to needs, here movies with Gross > 5e7 and rating > 7

# %%
df[(df['rating'] > 7) & (df['gross($)'] > 5e7)]
# Out:
#      movie_id                                title mpaa_rating  budget($)  \
# 1           2                   Driving Miss Daisy          PG    7500000
# 2           3                       Turner & Hooch          PG   13000000
# 3           4           Born on the Fourth of July           R   14000000
# 4           5                      Field of Dreams          PG   15000000
# 6           7              When Harry Met Sally...           R   16000000
# ..        ...                                  ...         ...        ...
# 505       506                           Big Hero 6          PG  165000000
# 506       507                         Interstellar       PG-13  165000000
# 507       508  Captain America: The Winter Soldier       PG-13  170000000
# 508       509       Dawn of the Planet of the Apes       PG-13  170000000
# 509       510              Guardians of the Galaxy       PG-13  170000000
#
#         gross($) release_date            genre  runtime(min)  rating  \
# ...

# %%
df[(df['rating'] > 7) & (df['gross($)'] > 5e7) & (df['mpaa_rating']=="PG")]
# Out:
#      movie_id                                     title mpaa_rating  \
# 1           2                        Driving Miss Daisy          PG
# 2           3                            Turner & Hooch          PG
# 4           5                           Field of Dreams          PG
# 7           8                        Dead Poets Society          PG
# 13         14                                    Batman          PG
# 15         16                        The Little Mermaid          PG
# 16         17                Back to the Future Part II          PG
# 19         20                           Steel Magnolias          PG
# 24         25                                Home Alone          PG
# 32         33                  The Hunt for Red October          PG
# 34         35               Back to the Future Part III          PG
# 45         46           Teenage Mutant Ninja Turtles II          PG
# 46         47                      Beauty and the Beast          PG
# ...

# %%
df[(df['rating'] > 7) & (df['genre'] == "Animation")]
# Out:
#      movie_id                             title mpaa_rating  budget($)  \
# 15         16                The Little Mermaid          PG   40000000
# 46         47              Beauty and the Beast          PG   25000000
# 65         66                           Aladdin           G   28000000
# 107       108                     The Lion King           G   45000000
# 123       124                         Toy Story           G   30000000
# 171       172                          Hercules           G   85000000
# 188       189               The Prince of Egypt          PG   70000000
# 191       192                             Mulan           G   90000000
# 194       195                      A Bug's Life           G  120000000
# 211       212                       Toy Story 2           G   90000000
# 215       216                            Tarzan          PG  150000000
# 241       242                             Shrek          PG   60000000
# ...

# %% [markdown]
# ### Counting the amount of values with shape function

# %%
df[(df['rating'] > 7) & (df['genre'] == "Animation")].shape[0]
# Out:
# 39

# %% [markdown]
# ### Counting the amount of values with len () function

# %%
len(df[(df['rating'] > 7) & (df['genre'] == "Animation")])
# Out:
# 39

# %% [markdown]
# ### Sorting and classifying values in ascending or descending order

# %%
sorted_budget = df.sort_values(by='budget($)', ascending=False)

sorted_budget.head(5)
# Out:
#      movie_id                                        title mpaa_rating  \
# 594       595                       Avengers: Infinity War       PG-13
# 454       455  Pirates of the Caribbean: On Stranger Tides       PG-13
# 614       615                            Avengers: Endgame       PG-13
# 574       575                     Star Wars: The Last Jedi       PG-13
# 375       376     Pirates of the Caribbean: At World's End       PG-13
#
#      budget($)      gross($) release_date            genre  runtime(min)  \
# 594  400000000  2.048000e+09     23-04-18           Action         149.0
# 454  380000000  1.045714e+09     14-05-11           Action         136.0
# 614  356000000  2.796000e+09     22-04-19           Action         181.0
# 574  317000000  1.333000e+09     09-12-19  Science Fiction         152.0
# 375  300000000  9.610000e+08     19-05-07        Adventure         169.0
#
#      rating  rating_count
# 594     6.9      240347.5
# 454     6.6      455211.0
# ...

# %%
sorted_budget_2 = df.nlargest(5, "budget($)")

sorted_budget_2
# Out:
#      movie_id                                        title mpaa_rating  \
# 594       595                       Avengers: Infinity War       PG-13
# 454       455  Pirates of the Caribbean: On Stranger Tides       PG-13
# 614       615                            Avengers: Endgame       PG-13
# 574       575                     Star Wars: The Last Jedi       PG-13
# 375       376     Pirates of the Caribbean: At World's End       PG-13
#
#      budget($)      gross($) release_date            genre  runtime(min)  \
# 594  400000000  2.048000e+09     23-04-18           Action         149.0
# 454  380000000  1.045714e+09     14-05-11           Action         136.0
# 614  356000000  2.796000e+09     22-04-19           Action         181.0
# 574  317000000  1.333000e+09     09-12-19  Science Fiction         152.0
# 375  300000000  9.610000e+08     19-05-07        Adventure         169.0
#
#      rating  rating_count
# 594     6.9      240347.5
# 454     6.6      455211.0
# ...

# %% [markdown]
# ### Sorting AND classifying in descendent order

# %%
 df_comedy_top_5 = df[df['genre'] == "Comedy"].sort_values(by='rating', ascending=False)

df_comedy_top_5.head(5)
# Out:
#      movie_id               title mpaa_rating  budget($)     gross($)  \
# 111       112        Forrest Gump       PG-13   55000000  677945399.0
# 185       186     The Truman Show          PG   60000000  264118201.0
# 254       255      Monsters, Inc.           G  115000000  562816256.0
# 80         81       Groundhog Day          PG   14600000   70906973.0
# 164       165  As Good as It Gets       PG-13   50000000  314178011.0
#
#     release_date   genre  runtime(min)  rating  rating_count
# 111     06-07-94  Comedy         142.0     8.8     1657851.0
# 185     04-06-98  Comedy         103.0     8.1      859224.0
# 254     01-11-01  Comedy          92.0     8.0      758349.0
# 80      11-02-93  Comedy         101.0     8.0      549538.0
# 164     19-12-97  Comedy         139.0     7.7      258974.0

# %% [markdown]
# ### Sorting Top 5 movies names by rating

# %%
df_top_5 = df.sort_values(by='rating', ascending=False)

df_top_5 .head(5)
# Out:
#      movie_id                                          title mpaa_rating  \
# 393       394                                The Dark Knight       PG-13
# 83         84                               Schindler's List           R
# 287       288  The Lord of the Rings: The Return of the King       PG-13
# 99        100                                   Pulp Fiction           R
# 98         99                              Jurassic Park III       PG-13
#
#      budget($)      gross($) release_date     genre  runtime(min)  rating  \
# 393  185000000  1.004558e+09     16-07-08    Action         152.0     9.0
# 83    22000000  3.213656e+08     29-11-93   History         195.0     8.9
# 287   94000000  1.118889e+09     01-12-03   Fantasy         201.0     8.9
# 99     8000000  2.139288e+08     10-09-94  Thriller         154.0     8.9
# 98    93000000  3.688000e+08     16-07-01  Thriller          92.0     8.9
#
#      rating_count
# 393     2127228.0
# 83      1117322.0
# 287     1529953.0
# ...

# %% [markdown]
# ### Converting date string values into datetime format DD-MM-YYYY

# %%
df['release_date']= pd.to_datetime(df['release_date'], format = ('%d-%m-%y'))

# %%
df_top_3_gross_romance = df[(df['genre'] == "Romance") & (df['release_date'].dt.year>1999)].sort_values(by='gross($)', ascending=False)

df_top_3_gross_romance.head(3)
# Out:
#      movie_id                                      title mpaa_rating  \
# 464       465  The Twilight Saga: Breaking Dawn - Part 2       PG-13
# 442       443  The Twilight Saga: Breaking Dawn - Part 1       PG-13
# 401       402                The Twilight Saga: New Moon       PG-13
#
#      budget($)     gross($) release_date    genre  runtime(min)  rating  \
# 464  120000000  829000000.0   2012-11-13  Romance         115.0     5.5
# 442  110000000  712171856.0   2011-03-15  Romance         117.0     4.9
# 401   50000000  709827462.0   2009-03-15  Romance         130.0     4.7
#
#      rating_count
# 464      218357.0
# 442      211592.0
# 401      252223.0

# %%
sr = pd.Series(df['genre'])
sr
# Out:
# 0        Romance
# 1         Comedy
# 2          Crime
# 3            War
# 4          Drama
#          ...
# 610    Adventure
# 611    Animation
# 612     Thriller
# 613        Drama
# 614       Action
# Name: genre, Length: 615, dtype: object

# %%
sr.value_counts()
# Out:
# genre
# Action             110
# Comedy              99
# Animation           87
# Drama               66
# Thriller            41
# Science Fiction     37
# Adventure           30
# Family              29
# Romance             28
# Fantasy             27
# Crime               17
# Horror              14
# Mystery             11
# War                  9
# Western              6
# History              4
# Name: count, dtype: int64

# %%
unique_genre = df['genre'].unique()

unique_genre
# Out:
# array(['Romance', 'Comedy', 'Crime', 'War', 'Drama', 'Family', 'Action',
#        'Animation', 'Science Fiction', 'Adventure', 'Thriller', 'Western',
#        'Horror', 'Mystery', 'History', 'Fantasy'], dtype=object)

# %%
len(unique_genre)
# Out:
# 16

# %%
df['genre'].nunique()
# Out:
# 16

# %%
df_top_5_budget_1999 = df[(df['release_date'].dt.year>1999)].sort_values(by='budget($)', ascending=False).head(5)

df_top_5_budget_1999
# Out:
#      movie_id                                        title mpaa_rating  \
# 594       595                       Avengers: Infinity War       PG-13
# 454       455  Pirates of the Caribbean: On Stranger Tides       PG-13
# 614       615                            Avengers: Endgame       PG-13
# 574       575                     Star Wars: The Last Jedi       PG-13
# 573       574                               Justice League       PG-13
#
#      budget($)      gross($) release_date            genre  runtime(min)  \
# 594  400000000  2.048000e+09   2018-04-23           Action         149.0
# 454  380000000  1.045714e+09   2011-05-14           Action         136.0
# 614  356000000  2.796000e+09   2019-04-22           Action         181.0
# 574  317000000  1.333000e+09   2019-12-09  Science Fiction         152.0
# 573  300000000  6.579000e+08   2017-11-15           Action         120.0
#
#      rating  rating_count
# 594     6.9      240347.5
# 454     6.6      455211.0
# ...

# %%
frequence_mpaa_1 = pd.Series(df['mpaa_rating'])

frequence_mpaa_1
# Out:
# 0      PG-13
# 1         PG
# 2         PG
# 3          R
# 4         PG
#        ...
# 610    PG-13
# 611        G
# 612    PG-13
# 613       PG
# 614    PG-13
# Name: mpaa_rating, Length: 615, dtype: object

# %%
frequence_mpaa_2 = frequence_mpaa_1.value_counts()

# %%
frequence_mpaa_2
# Out:
# mpaa_rating
# PG-13    285
# PG       161
# R        142
# G         27
# Name: count, dtype: int64

# %%
first_mpaa_rating = frequence_mpaa_2.index[0]
first_value = frequence_mpaa_2.iloc[0]

last_mpaa_rating = frequence_mpaa_2.index[-1]
last_value = frequence_mpaa_2.iloc[-1]

print(first_mpaa_rating, first_value)
print(last_mpaa_rating, last_value)
# Out:
# PG-13 285
# G 27

# %%
most_least_genre = df.groupby('genre')['budget($)'].mean().sort_values(ascending=False)

most_least_genre
# Out:
# genre
# Fantasy            1.612111e+08
# Action             1.441682e+08
# Adventure          1.338333e+08
# Science Fiction    1.267838e+08
# Animation          1.158793e+08
# Mystery            1.035455e+08
# War                9.075556e+07
# Thriller           8.658537e+07
# Western            7.983333e+07
# Family             6.268966e+07
# Crime              5.658824e+07
# Drama              5.592576e+07
# History            5.550000e+07
# Comedy             4.957727e+07
# Romance            4.540020e+07
# Horror             3.700429e+07
# Name: budget($), dtype: float64

# %%
first_genre= most_least_genre.index[0]
first_value = most_least_genre.iloc[0]

last_genre = most_least_genre.index[-1]
last_value = most_least_genre.iloc[-1]

print(first_genre, first_value)
print(last_genre, last_value)
# Out:
# Fantasy 161211111.1111111
# Horror 37004285.71428572

# %%
preferred_genre = df.groupby('genre')['rating'].mean().sort_values(ascending=False)

preferred_genre
# Out:
# genre
# History            7.625000
# War                7.355556
# Fantasy            7.337037
# Western            7.333333
# Drama              7.193939
# Science Fiction    7.151351
# Animation          7.110345
# Thriller           6.995122
# Action             6.985455
# Crime              6.876471
# Mystery            6.827273
# Horror             6.735714
# Adventure          6.696667
# Comedy             6.631313
# Romance            6.400000
# Family             6.117241
# Name: rating, dtype: float64

# %%
amount_ratings = df.groupby('genre')['rating'].value_counts().sort_values(ascending=True)

amount_ratings
# Out:
# genre      rating
# Drama      5.9        1
# Fantasy    6.2        1
#            5.7        1
#            6.1        1
#            6.5        1
#                      ..
# Drama      6.9       10
# Thriller   6.9       10
# Comedy     6.9       15
# Animation  6.9       28
# Action     6.9       38
# Name: count, Length: 281, dtype: int64

# %%
mean_rating = df['rating'].mean()

x_quantile_50 = df['rating_count'].quantile(0.50)

# %%
def weighted_rating (movie, x_quantile_50=x_quantile_50, mean_rating=mean_rating):
    m = movie ['rating_count']
    r = movie ['rating']
    return (m/(m+x_quantile_50)*r) + (x_quantile_50/(x_quantile_50+m)*mean_vote)

# %%
df['weighted_rating'] = df.apply(weighted_rating, axis=1)

favourite_genre = df.groupby('genre')["weighted_rating"].mean().sort_values (ascending=False)

favourite_genre
# Out:
# genre
# History            7.427311
# Fantasy            7.301850
# Western            7.270464
# War                7.207926
# Drama              7.136233
# Science Fiction    7.123499
# Animation          7.083491
# Thriller           7.056049
# Action             7.021581
# Crime              6.989374
# Mystery            6.950203
# Adventure          6.910464
# Comedy             6.865684
# Horror             6.858611
# Family             6.733358
# Romance            6.727942
# Name: weighted_rating, dtype: float64
